# %%
import rospy
import threading
from std_msgs.msg import String

from eris.eris import Eris

from threading import Thread,Lock

from time import sleep
dataMutex=Lock()

#What to read from Eris
#Set up Eris driver to read these features


features=['saludo','Analog','Sine']
types=['char','float','float']
length=[4,5,5]
port='/dev/ttyACM0'

e=Eris(features,types,length,port)

pub = rospy.Publisher('chatt', String, queue_size=10)
#Data buffer
nums=[];

def publishData(data):
    #Make a local copy of the data
    dataMutex.acquire(1)
    local=list(data)
    dataMutex.release()
    a=e.parse(local)
    for i,sample in enumerate(a):
        print('Sample'+str(i))
        print(sample)


rospy.init_node('talker', anonymous=True)
rate = rospy.Rate(2) # 10hz 
e.sendCommand('S_ON') #Initilize automatic streaming of data
print('Inicio')
for i in range(0,10):
    #Get data from teensy
    dataMutex.acquire(1)    
    d=e.read()
    dataMutex.release()
    if len(d)>0:
        t=Thread(target=publishData,args=(d,))
        t.start()             
    rate.sleep()
e.sendCommand('S_OFF')
e.stop()
# Out:
# What?
# <<ERROR>>Unsupported command<<ERROR>>
#
# Eris is ready
# Inicio
# Sample0
# {'Sine': [3.0543272495269775, 3.0551116466522217, 3.0558950901031494, 3.0566768646240234, 3.057457685470581], 'saludo': ['h', 'o', 'l', 'a'], 'Analog': [0.7186523079872131, 1.121484398841858, 0.841113269329071, 0.9603515267372131, 0.9249023199081421]}
# Sample0
# {'Sine': [3.0963900089263916, 3.097106456756592, 3.0978217124938965, 3.0985357761383057, nan], 'saludo': ['h', 'o', 'l', 'a'], 'Analog': [0.82177734375, 0.915234386920929, 0.866894543170929, 1.01513671875, nan]}
# Sample1
# {'Sine': [3.1104862689971924, 3.111178159713745, 3.1118688583374023, 3.112558126449585, nan], 'saludo': ['h', 'o', 'l', 'a'], 'Analog': [0.8604491949081421, 0.760546863079071, 0.8765624761581421, 0.8636718392372131, nan]}
# Sample2
# {'Sine': [3.1240909099578857, 3.124758243560791, 3.125424385070801, 3.126089096069336, nan], 'saludo': ['h', 'o', 'l', 'a'], 'Analog': [0.8604491949081421, 0.931347668170929, 0.95068359375, 1.053808569908142, nan]}
# Sample0
# {'Sine': [3.137202501296997, 3.137845039367676, 3.138486385345459, 3.1391265392303467, nan], 'saludo': ['h', 'o', 'l', 'a'], 'Analog': [0.953906238079071, 0.5897460579872131, 0.6509765386581421, 1.1569335460662842, nan]}
# Sample1
# {'Sine': [3.1498186588287354, 3.1504364013671875, 3.151052951812744, 3.1516683101654053, nan], 'saludo': ['h', 'o', 'l', 'a'], 'Analog': [0.8765624761581421, 0.6219726204872131, 0.9281249642372131, 0.9345703125, nan]}
# Sample0
# {'Sine': [3.1619374752044678, 3.1625301837921143, 3.1631219387054443, 3.1637122631073, nan], 'saludo': ['h', 'o', 'l', 'a'], 'Analog': [0.641308605670929, 0.889453113079071, 1.2858397960662842, 0.931347668170929, nan]}
# Sample1
# {'Sine': [3.1735570430755615, 3.1741247177124023, 3.1746912002563477, 3.1752567291259766, nan], 'saludo': ['h', 'o', 'l', 'a'], 'Analog': [0.647753894329071, 0.7959960699081421, 1.008691430091858, 0.792773425579071, nan]}
# Sample2
# {'Sine': [3.1846752166748047, 3.18521785736084, 3.1857593059539795, 3.1862995624542236, nan], 'saludo': ['h', 'o', 'l', 'a'], 'Analog': [1.1472655534744263, 0.721875011920929, 0.963574230670929, 0.792773425579071, nan]}
# Sample0
# {'Sine': [3.1952905654907227, 3.195808172225952, 3.196324348449707, 3.1968393325805664, nan], 'saludo': ['h', 'o', 'l', 'a'], 'Analog': [0.837890625, 0.7734375, 0.931347668170929, 0.7315429449081421, nan]}
# Sample1
# {'Sine': [3.2054014205932617, 3.2058937549591064, 3.2063846588134766, 3.206874370574951, nan], 'saludo': ['h', 'o', 'l', 'a'], 'Analog': [0.8604491949081421, 0.657421886920929, 1.0666991472244263, 0.866894543170929, nan]}
# Sample0
# {'Sine': [3.215006113052368, 3.215472936630249, 3.2159385681152344, 3.216403007507324, nan], 'saludo': ['h', 'o', 'l', 'a'], 'Analog':
nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.8765624761581421, nan, nan, nan, nan],
#   'Sine': [3.291832208633423, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.7637695074081421, nan, nan, nan, nan],
#   'Sine': [3.2919774055480957, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.33837890625, nan, nan, nan, nan],
#   'Sine': [3.292121171951294, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.37382811307907104, nan, nan, nan, nan],
#   'Sine': [3.2922637462615967, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.515625, nan, nan, nan, nan],
#   'Sine': [3.292405128479004, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.48017576336860657, nan, nan, nan, nan],
#   'Sine': [3.2925448417663574, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.4124999940395355, nan, nan, nan, nan],
#   'Sine': [3.2926836013793945, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.567187488079071, nan, nan, nan, nan],
#   'Sine': [3.292820930480957, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [1.121484398841858, nan, nan, nan, nan],
#   'Sine': [3.292957067489624, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.953906238079071, nan, nan, nan, nan],
#   'Sine': [3.2930917739868164, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.9732421636581421, nan, nan, nan, nan],
#   'Sine': [3.2932252883911133, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.9571288824081421, nan, nan, nan, nan],
#   'Sine': [3.2933573722839355, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.679980456829071, nan, nan, nan, nan],
#   'Sine': [3.2934882640838623, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.9603515267372131, nan, nan, nan, nan],
#   'Sine': [3.2936177253723145, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.915234386920929, nan, nan, nan, nan],
#   'Sine': [3.293745994567871, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.7637695074081421, nan, nan, nan, nan],
#   'Sine': [3.293872833251953, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.8701171875, nan, nan, nan, nan],
#   'Sine': [3.2939984798431396, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.59619140625, nan, nan, nan, nan],
#   'Sine': [3.2941229343414307, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.8443359136581421, nan, nan, nan, nan],
#   'Sine': [3.294245958328247, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.8056640625, nan, nan, nan, nan],
#   'Sine': [3.294367790222168, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.8443359136581421, nan, nan, nan, nan],
#   'Sine': [3.2944881916046143, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.59619140625, nan, nan, nan, nan],
#   'Sine': [3.294607162475586, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.6123046875, nan, nan, nan, nan],
#   'Sine': [3.294725179672241, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [1.089257836341858, nan, nan, nan, nan],
#   'Sine': [3.2948415279388428, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.841113269329071, nan, nan, nan, nan],
#   'Sine': [3.294956922531128, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.9410156011581421, nan, nan, nan, nan],
#   'Sine': [3.2950708866119385, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [1.1311522722244263, nan, nan, nan, nan],
#   'Sine': [3.2951834201812744, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.8475585579872131, nan, nan, nan, nan],
#   'Sine': [3.295294761657715, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.986132800579071, nan, nan, nan, nan],
#   'Sine': [3.2954046726226807, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.7154296636581421, nan, nan, nan, nan],
#   'Sine': [3.29551362991333, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.883007824420929, nan, nan, nan, nan],
#   'Sine': [3.295620918273926, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']},
#  {'Analog': [0.696093738079071, nan, nan, nan, nan],
#   'Sine': [3.295727014541626, nan, nan, nan, nan],
#   'saludo': ['h', 'o', 'l', 'a']}]

# %%
list(d[1][0:1])

# %%
e.sendCommand('S_OFF')
e.stop()
# Out:
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# <ipython-input-7-5e4969b665b6> in <module>()
# ----> 1 e.sendCommand('S_OFF')
#       2 e.stop()
#
# /home/ossip/Dropbox/LIBRERIAS/LIBRERIA_PYTHON/eris/eris.py in sendCommand(self, command)
#      62         def sendCommand(self,command):
#      63             cmd=''.join([command,'\n'])
# ---> 64             self.port.write(str.encode(cmd))
#      65             self.port.flush()
#      66
#
# /usr/lib/python2.7/dist-packages/serial/serialposix.pyc in write(self, data)
#     529         """Output the given byte string over the serial port."""
#     530         if not self.is_open:
# --> 531             raise portNotOpenError
#     532         d = to_bytes(data)
#     533         tx_len = length = len(d)
#
# SerialException: Attempting to use a port that is not open
